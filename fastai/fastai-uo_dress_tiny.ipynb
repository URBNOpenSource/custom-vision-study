# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *
from pathlib import Path
import util
import warnings
warnings.filterwarnings(action='once')

# %% [markdown]
# ## User Params

# %%
basepath = Path('/home/jupyter/data')
dataset_name = 'uo_dress_tiny'
n_epoch = 100

# %% [markdown]
# ## Derived Params and Helpers

# %%
path_img = basepath/'imagenet_style'/dataset_name
labels_file = basepath/dataset_name/'labels.csv'

# %%
def create_learner(data, savename='dummy', patience=8, modeltype=models.resnet34):
    learn = create_cnn(data, 
                       modeltype, 
                       metrics=error_rate, 
                       callback_fns=[partial(SaveModelCallback, name=savename), 
                                     partial(EarlyStoppingCallback, patience=patience),
                                     ShowGraph])   
    return learn

# %% [markdown]
# ## Create dataset

# %%
data = ImageDataBunch.from_folder(path_img, 
                                  train='train', 
                                  valid='valid', 
                                  test='test', 
                                  ds_tfms=get_transforms(), 
                                  size=224)
data.normalize(imagenet_stats)

# %%
print(data.classes)
# Out:
# ['floral', 'not_dress', 'solid_color', 'stripes']

# %% [markdown]
# ## Display dataset

# %%
data.show_batch(rows=6)

# %% [markdown]
# ## Train a standard transfer learning model (stage 1)

# %%
learn = create_learner(data, 'stage1-bestmodel')
learn.fit_one_cycle(n_epoch)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='31' class='' max='100', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       31.00% [31/100 02:50<06:18]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.646527</th>
#     <th>1.230327</th>
#     <th>0.583333</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.443721</th>
#     <th>0.972421</th>
#     <th>0.305556</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>1.236126</th>
#     <th>0.850011</th>
#     <th>0.277778</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>1.085137</th>
#     <th>0.799663</th>
#     <th>0.277778</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.957492</th>
#     <th>0.772311</th>
#     <th>0.305556</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.847049</th>
#     <th>0.765362</th>
#     <th>0.305556</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.756205</th>
#     <th>0.765556</th>
#     <th>0.305556</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.680475</th>
#     <th>0.749770</th>
#     <th>0.305556</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.618465</th>
#     <th>0.742756</th>
#     <th>0.305556</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.566527</th>
#     <th>0.760890</th>
#     <th>0.305556</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.517046</th>
#     <th>0.727102</th>
#     <th>0.305556</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.469025</th>
#     <th>0.727669</th>
#     <th>0.305556</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.423229</th>
#     <th>0.722781</th>
#     <th>0.305556</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.381260</th>
#     <th>0.746770</th>
#     <th>0.305556</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.345065</th>
#     <th>0.726047</th>
#     <th>0.305556</th>
#   </tr>
#   <tr>
#     <th>16</th>
#     <th>0.315324</th>
#     <th>0.718608</th>
#     <th>0.277778</th>
#   </tr>
#   <tr>
#     <th>17</th>
#     <th>0.285229</th>
#     <th>0.761483</th>
#     <th>0.305556</th>
#   </tr>
#   <tr>
#     <th>18</th>
#     <th>0.261712</th>
#     <th>0.745952</th>
#     <th>0.333333</th>
#   </tr>
#   <tr>
#     <th>19</th>
#     <th>0.239374</th>
#     <th>0.751963</th>
#     <th>0.333333</th>
#   </tr>
#   <tr>
#     <th>20</th>
#     <th>0.217617</th>
#     <th>0.770587</th>
#     <th>0.277778</th>
#   </tr>
#   <tr>
#     <th>21</th>
#     <th>0.198665</th>
#     <th>0.813695</th>
#     <th>0.277778</th>
#   </tr>
#   <tr>
#     <th>22</th>
#     <th>0.180096</th>
#     <th>0.778953</th>
#     <th>0.250000</th>
#   </tr>
#   <tr>
#     <th>23</th>
#     <th>0.165009</th>
#     <th>0.692464</th>
#     <th>0.222222</th>
#   </tr>
#   <tr>
#     <th>24</th>
#     <th>0.148280</th>
#     <th>0.690444</th>
#     <th>0.250000</th>
#   </tr>
#   <tr>
#     <th>25</th>
#     <th>0.134559</th>
#     <th>0.765973</th>
#     <th>0.222222</th>
#   </tr>
#   <tr>
#     <th>26</th>
#     <th>0.122297</th>
#     <th>0.809372</th>
#     <th>0.250000</th>
#   </tr>
#   <tr>
#     <th>27</th>
#     <th>0.110290</th>
#     <th>0.811179</th>
#     <th>0.250000</th>
#   </tr>
#   <tr>
#     <th>28</th>
#     <th>0.100839</th>
#     <th>0.807034</th>
#     <th>0.250000</th>
#   </tr>
#   <tr>
#     <th>29</th>
#     <th>0.091326</th>
#     <th>0.815232</th>
#     <th>0.250000</th>
#   </tr>
#   <tr>
#     <th>30</th>
#     <th>0.084979</th>
#     <th>0.933831</th>
#     <th>0.277778</th>
#   </tr>
#   <tr>
#     <th>31</th>
#     <th>0.077330</th>
#     <th>0.971210</th>
#     <th>0.305556</th>
#   </tr>
#   <tr>
#
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>
# Epoch 32: early stopping

# %% [markdown]
# ### Show results from generic evaluation tool

# %%
results_val = util.eval_rollup(labels_file, learn, evalset='val')
# Out:
# Dataset: val
# {'sklearn': {'acc': 0.75,
#              'auc_avg': 0.9558035714285715,
#              'auc_indiv': array([0.986607, 0.986607, 0.930769, 0.919231]),
#              'confmat': array([[7, 0, 0, 1],
#        [1, 6, 1, 0],
#        [1, 0, 8, 1],
#        [0, 0, 4, 6]]),
#              'report': '             precision    recall  f1-score   support\n'
#                        '\n'
#                        '     floral       0.78      0.88      0.82         8\n'
#                        '  not_dress       1.00      0.75      0.86         8\n'
#                        'solid_color       0.62      0.80      0.70        10\n'
#                        '    stripes       0.75      0.60      0.67        10\n'
#                        '\n'
#                        'avg / total       0.77      0.75      0.75        '
#                        '36\n'}}
# /home/jupyter/tutorials/util.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_keep['name'] = [d.split('/')[-1] for d in df_keep.name.tolist()]

# %%
results_test, y_true, y_pred, scores, class_labels = util.eval_rollup(labels_file, learn, evalset='test')
# Out:
# Dataset: test
# {'sklearn': {'acc': 0.8532110091743119,
#              'auc_avg': 0.9696157290488588,
#              'auc_indiv': array([0.971237, 0.961277, 0.961645, 0.984304]),
#              'confmat': array([[124,   0,   9,   9],
#        [  4,  63,   6,   2],
#        [ 24,   1, 238,  21],
#        [  3,   0,   1,  40]]),
#              'report': '             precision    recall  f1-score   support\n'
#                        '\n'
#                        '     floral       0.80      0.87      0.84       142\n'
#                        '  not_dress       0.98      0.84      0.91        75\n'
#                        'solid_color       0.94      0.84      0.88       284\n'
#                        '    stripes       0.56      0.91      0.69        44\n'
#                        '\n'
#                        'avg / total       0.88      0.85      0.86       '
#                        '545\n'}}

# %% [markdown]
# ### Show results using FastAI to confirm matches

# %%
# Confirm fastai reporting matching the generic one used for other platforms
# Some formatting work needed below to run on test and not validation dataset
y_true_num = tensor([data.classes.index(z) for z in y_true])  # Convert strings to numbers (tensor)
preds,y,losses = learn.get_preds(with_loss=True, is_test=True)
interp = ClassificationInterpretation(data, preds, tensor(y_true_num), losses)
#interp.plot_top_losses(15, figsize=(15,11))
interp.plot_confusion_matrix(figsize=(6,6), dpi=60)

# %% [markdown]
# Fastai confusion matrix matches the generic one for the test dataset.

# %% [markdown]
# ## Unfreezing, fine-tuning, and learning rates

# %% [markdown]
# First let's try just unfreezing the previously trained model and continue running some more training to see how well it can do.

# %%
learn = create_learner(data, 'unfreeze-bestmodel')
learn.load('stage1-bestmodel')
learn.unfreeze()
learn.fit_one_cycle(n_epoch)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='11' class='' max='100', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       11.00% [11/100 01:12<09:45]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.046998</th>
#     <th>1.233426</th>
#     <th>0.277778</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.042858</th>
#     <th>1.064148</th>
#     <th>0.277778</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.031728</th>
#     <th>1.064530</th>
#     <th>0.222222</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.032214</th>
#     <th>1.063919</th>
#     <th>0.250000</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.038958</th>
#     <th>1.186307</th>
#     <th>0.250000</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.047192</th>
#     <th>1.276347</th>
#     <th>0.166667</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.066768</th>
#     <th>1.079137</th>
#     <th>0.250000</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.080508</th>
#     <th>2.566189</th>
#     <th>0.333333</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.086515</th>
#     <th>1.447432</th>
#     <th>0.277778</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.096337</th>
#     <th>1.999362</th>
#     <th>0.305556</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.097656</th>
#     <th>2.660264</th>
#     <th>0.333333</th>
#   </tr>
#   <tr>
#
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>
# Epoch 12: early stopping

# %%
results_test, y_true, y_pred, scores, class_labels = util.eval_rollup(labels_file, learn, evalset='test')
# Out:
# Dataset: test
# {'sklearn': {'acc': 0.8201834862385321,
#              'auc_avg': 0.9662152803455473,
#              'auc_indiv': array([0.960953, 0.960397, 0.959865, 0.983646]),
#              'confmat': array([[124,   0,   4,  14],
#        [  5,  63,   5,   2],
#        [ 13,   5, 217,  49],
#        [  1,   0,   0,  43]]),
#              'report': '             precision    recall  f1-score   support\n'
#                        '\n'
#                        '     floral       0.87      0.87      0.87       142\n'
#                        '  not_dress       0.93      0.84      0.88        75\n'
#                        'solid_color       0.96      0.76      0.85       284\n'
#                        '    stripes       0.40      0.98      0.57        44\n'
#                        '\n'
#                        'avg / total       0.89      0.82      0.84       '
#                        '545\n'}}

# %% [markdown]
# ## Unfreeze but use identified learning rates

# %% [markdown]
# Now let's go back to the original model that only trained the head again.
# But this time, we'll find the best learning rate to use for this, and then use those learning rates with the unfrozen model.

# %% [markdown]
# First, find and plot the learning rates using lr_find.

# %%
learn = create_learner(data)
learn.load('stage1-bestmodel')
learn.callback_fns = [Recorder]  # Need to flush callbacks or else lr_find crashes    
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# Now that we have the learning rate range, let's feed that into the model and rerun

# %%
# Reload with new savename
learn = create_learner(data, 'unfreeze-lrfind-bestmodel')
learn.load('stage1-bestmodel')

# Unfreeze and kick off 
learn.unfreeze()
learn.fit_one_cycle(n_epoch, max_lr=slice(1e-5,1e-3))
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='8' class='' max='100', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       8.00% [8/100 00:51<09:56]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.051929</th>
#     <th>0.729746</th>
#     <th>0.250000</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.044526</th>
#     <th>0.757826</th>
#     <th>0.250000</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.037665</th>
#     <th>0.782527</th>
#     <th>0.250000</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.036705</th>
#     <th>0.802086</th>
#     <th>0.250000</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.031478</th>
#     <th>0.780262</th>
#     <th>0.222222</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.027322</th>
#     <th>0.772532</th>
#     <th>0.194444</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.025415</th>
#     <th>0.775224</th>
#     <th>0.194444</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.023681</th>
#     <th>0.764741</th>
#     <th>0.166667</th>
#   </tr>
#   <tr>
#
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:00<00:00]
#     </div>
# Epoch 9: early stopping

# %%
results_test, y_true, y_pred, scores, class_labels = util.eval_rollup(labels_file, learn, evalset='test')
# Out:
# Dataset: test
# {'sklearn': {'acc': 0.8678899082568807,
#              'auc_avg': 0.9713057481103109,
#              'auc_indiv': array([0.972128, 0.963149, 0.964236, 0.98571 ]),
#              'confmat': array([[126,   0,   8,   8],
#        [  4,  63,   6,   2],
#        [ 24,   1, 245,  14],
#        [  3,   0,   2,  39]]),
#              'report': '             precision    recall  f1-score   support\n'
#                        '\n'
#                        '     floral       0.80      0.89      0.84       142\n'
#                        '  not_dress       0.98      0.84      0.91        75\n'
#                        'solid_color       0.94      0.86      0.90       284\n'
#                        '    stripes       0.62      0.89      0.73        44\n'
#                        '\n'
#                        'avg / total       0.88      0.87      0.87       '
#                        '545\n'}}

# %% [markdown]
# ## Try Resnet50

# %%
data = ImageDataBunch.from_folder(path_img, 
                                  train='train', 
                                  valid='valid', 
                                  test='test', 
                                  ds_tfms=get_transforms(), 
                                  size=299,
                                  bs=32)
data.normalize(imagenet_stats)

# %% [markdown]
# ### Try training just the head

# %%
learn = create_learner(data, 'resnet50-stage1-bestmodel', modeltype=models.resnet50)
learn.fit_one_cycle(n_epoch)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='15' class='' max='100', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       15.00% [15/100 03:39<20:41]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.335673</th>
#     <th>0.947858</th>
#     <th>0.333333</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.961779</th>
#     <th>0.723880</th>
#     <th>0.277778</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.733028</th>
#     <th>0.666178</th>
#     <th>0.222222</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.584894</th>
#     <th>0.672793</th>
#     <th>0.250000</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.480768</th>
#     <th>0.640416</th>
#     <th>0.166667</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.396692</th>
#     <th>0.584956</th>
#     <th>0.166667</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.350880</th>
#     <th>0.543594</th>
#     <th>0.166667</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.311694</th>
#     <th>0.532284</th>
#     <th>0.166667</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.267389</th>
#     <th>0.637977</th>
#     <th>0.250000</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.228441</th>
#     <th>0.675942</th>
#     <th>0.277778</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.194661</th>
#     <th>0.624085</th>
#     <th>0.277778</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.169307</th>
#     <th>0.601566</th>
#     <th>0.222222</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.141337</th>
#     <th>0.615373</th>
#     <th>0.222222</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.118805</th>
#     <th>0.551417</th>
#     <th>0.222222</th>
#   </tr>
#   <tr>
#     <th>15</th>
#     <th>0.106954</th>
#     <th>0.663177</th>
#     <th>0.222222</th>
#   </tr>
#   <tr>
#
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:01<00:00]
#     </div>
# Epoch 16: early stopping

# %%
results_test, y_true, y_pred, scores, class_labels = util.eval_rollup(labels_file, learn, evalset='test')
# Out:
# Dataset: test
# {'sklearn': {'acc': 0.8678899082568807,
#              'auc_avg': 0.9641312855665666,
#              'auc_indiv': array([0.968423, 0.951716, 0.955075, 0.98131 ]),
#              'confmat': array([[126,   0,   8,   8],
#        [  3,  64,   7,   1],
#        [ 17,   1, 243,  23],
#        [  1,   0,   3,  40]]),
#              'report': '             precision    recall  f1-score   support\n'
#                        '\n'
#                        '     floral       0.86      0.89      0.87       142\n'
#                        '  not_dress       0.98      0.85      0.91        75\n'
#                        'solid_color       0.93      0.86      0.89       284\n'
#                        '    stripes       0.56      0.91      0.69        44\n'
#                        '\n'
#                        'avg / total       0.89      0.87      0.87       '
#                        '545\n'}}

# %% [markdown]
# ### Unfreeze, finetune with learning rates

# %% [markdown]
# Get the learning rate separately, like before

# %%
learn = create_learner(data, modeltype=models.resnet50)
learn.load('resnet50-stage1-bestmodel')
learn.callback_fns = [Recorder]  # Need to flush callbacks or else lr_find crashes    
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# Reload the transfer learning results, unfreeze, and train using the range of learning rates.

# %%
# Reload with new savename
learn = create_learner(data, 'resnet50-unfreeze-lrfind-bestmodel', modeltype=models.resnet50)
learn.load('resnet50-stage1-bestmodel')

# Unfreeze and kick off 
learn.unfreeze()
learn.fit_one_cycle(n_epoch, max_lr=slice(1e-6,1e-4))
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12' class='' max='100', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       12.00% [12/100 03:25<25:09]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.169101</th>
#     <th>0.549504</th>
#     <th>0.166667</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.139823</th>
#     <th>0.542504</th>
#     <th>0.166667</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.145475</th>
#     <th>0.540222</th>
#     <th>0.194444</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.138996</th>
#     <th>0.527023</th>
#     <th>0.166667</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.118736</th>
#     <th>0.506370</th>
#     <th>0.194444</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.114873</th>
#     <th>0.510809</th>
#     <th>0.194444</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.105810</th>
#     <th>0.508579</th>
#     <th>0.222222</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.101576</th>
#     <th>0.519954</th>
#     <th>0.194444</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.108423</th>
#     <th>0.519251</th>
#     <th>0.194444</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.100442</th>
#     <th>0.521116</th>
#     <th>0.194444</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.093039</th>
#     <th>0.514122</th>
#     <th>0.194444</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.085710</th>
#     <th>0.511043</th>
#     <th>0.222222</th>
#   </tr>
#   <tr>
#
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1/1 00:01<00:00]
#     </div>
# Epoch 13: early stopping

# %%
results_test, y_true, y_pred, scores, class_labels = util.eval_rollup(labels_file, learn, evalset='test')
# Out:
# Dataset: test
# {'sklearn': {'acc': 0.8623853211009175,
#              'auc_avg': 0.9651093191910639,
#              'auc_indiv': array([0.970171, 0.951121, 0.956883, 0.982263]),
#              'confmat': array([[124,   0,  11,   7],
#        [  2,  64,   7,   2],
#        [ 17,   1, 241,  25],
#        [  0,   0,   3,  41]]),
#              'report': '             precision    recall  f1-score   support\n'
#                        '\n'
#                        '     floral       0.87      0.87      0.87       142\n'
#                        '  not_dress       0.98      0.85      0.91        75\n'
#                        'solid_color       0.92      0.85      0.88       284\n'
#                        '    stripes       0.55      0.93      0.69        44\n'
#                        '\n'
#                        'avg / total       0.88      0.86      0.87       '
#                        '545\n'}}
