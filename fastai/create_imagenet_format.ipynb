# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *
from pathlib import Path
import os, sys
import pandas as pd
import shutil
from sklearn.externals.joblib import Parallel, delayed

# %% [markdown]
# # Create Imagenet Style Folders

# %% [markdown]
# It's much easier to just convert our file structure to imagenet standard instead of create a custom ImageData bunch. The Imagenet format is:
#
# path\
#   train\
#     clas1\
#     clas2\
#     ...
#   valid\
#     clas1\
#     clas2\
#     ...
#   test\
#
# Whereas our format is:
#
# path\
#   labels.csv
#   train\
#     (all class)
#   test\
#     (all class)
#   val\
#     (all class)

# %% [markdown]
# ## Directions

# %% [markdown]
# 1. Download gzipped data files
# 2. Untar all the files so you have directories

# %%
base_path = Path('/home/jupyter/data')
orig_datasets = ['uo_dress', 'uo_dress_tiny', 'cifar10', 'cifar10_tiny', 'mnist', 'mnist_tiny', 'fashion_mnist', 'fashion_mnist_tiny']
split_names = [('train', 'train'), 
               ('val', 'valid'), 
               ('test', 'test')]
dst_base = base_path/'imagenet_style'

# %% [markdown]
# ## Create output dir

# %%
for dataset in orig_datasets:
    print('Copying {}'.format(dataset))
    dst_path = dst_base/dataset
    os.makedirs(dst_path, exist_ok=True)

    # Read labels file
    df = pd.read_csv(base_path/dataset/'labels.csv', delimiter=',', header=None, names=['name','label'])

    # Get unique classes
    class_labels = df.label.unique()

    # Create output directories
    for split in split_names:
        src_split = split[0]
        dst_split = split[1]
        print('\tCopying {}/{}'.format(dataset, dst_split))        

        for label in class_labels:
            label_str = str(label)
            src_path = base_path/dataset
            if split[1] == 'test':
                save_path = dst_path/dst_split
            else:
                save_path = dst_path/dst_split/label_str
            print('\t\tCopying {}'.format(save_path))        

            # Create directory
            os.makedirs(save_path, exist_ok=True)        

            # Get matching values
            matches = df[(df.name.str.contains(src_split)) & (df.label==label)].name.tolist()

            # Parallel copy files to proper locations
            Parallel(n_jobs=-1)(delayed(shutil.copy)(src_path/fname, save_path) for fname in matches)
# Out:
# Copying uo_dress
# 	Copying uo_dress/train
# 		Copying /home/jupyter/data/imagenet_style/uo_dress/train/not_dress
# 		Copying /home/jupyter/data/imagenet_style/uo_dress/train/solid_color
# 		Copying /home/jupyter/data/imagenet_style/uo_dress/train/floral
# 		Copying /home/jupyter/data/imagenet_style/uo_dress/train/stripes
# 	Copying uo_dress/valid
# 		Copying /home/jupyter/data/imagenet_style/uo_dress/valid/not_dress
# 		Copying /home/jupyter/data/imagenet_style/uo_dress/valid/solid_color
# 		Copying /home/jupyter/data/imagenet_style/uo_dress/valid/floral
# 		Copying /home/jupyter/data/imagenet_style/uo_dress/valid/stripes
# 	Copying uo_dress/test
# 		Copying /home/jupyter/data/imagenet_style/uo_dress/test
# 		Copying /home/jupyter/data/imagenet_style/uo_dress/test
# 		Copying /home/jupyter/data/imagenet_style/uo_dress/test
# 		Copying /home/jupyter/data/imagenet_style/uo_dress/test
# Copying uo_dress_tiny
# 	Copying uo_dress_tiny/train
# 		Copying /home/jupyter/data/imagenet_style/uo_dress_tiny/train/floral
# 		Copying /home/jupyter/data/imagenet_style/uo_dress_tiny/train/not_dress
# 		Copying /home/jupyter/data/imagenet_style/uo_dress_tiny/train/solid_color
# 		Copying /home/jupyter/data/imagenet_style/uo_dress_tiny/train/stripes
# 	Copying uo_dress_tiny/valid
# 		Copying /home/jupyter/data/imagenet_style/uo_dress_tiny/valid/floral
# 		Copying /home/jupyter/data/imagenet_style/uo_dress_tiny/valid/not_dress
# 		Copying /home/jupyter/data/imagenet_style/uo_dress_tiny/valid/solid_color
# 		Copying /home/jupyter/data/imagenet_style/uo_dress_tiny/valid/stripes
# 	Copying uo_dress_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/uo_dress_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/uo_dress_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/uo_dress_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/uo_dress_tiny/test
# Copying cifar10
# 	Copying cifar10/train
# 		Copying /home/jupyter/data/imagenet_style/cifar10/train/6
# 		Copying /home/jupyter/data/imagenet_style/cifar10/train/9
# 		Copying /home/jupyter/data/imagenet_style/cifar10/train/4
# 		Copying /home/jupyter/data/imagenet_style/cifar10/train/1
# 		Copying /home/jupyter/data/imagenet_style/cifar10/train/2
# 		Copying /home/jupyter/data/imagenet_style/cifar10/train/7
# 		Copying /home/jupyter/data/imagenet_style/cifar10/train/8
# 		Copying /home/jupyter/data/imagenet_style/cifar10/train/3
# 		Copying /home/jupyter/data/imagenet_style/cifar10/train/5
# 		Copying /home/jupyter/data/imagenet_style/cifar10/train/0
# 	Copying cifar10/valid
# 		Copying /home/jupyter/data/imagenet_style/cifar10/valid/6
# 		Copying /home/jupyter/data/imagenet_style/cifar10/valid/9
# 		Copying /home/jupyter/data/imagenet_style/cifar10/valid/4
# 		Copying /home/jupyter/data/imagenet_style/cifar10/valid/1
# 		Copying /home/jupyter/data/imagenet_style/cifar10/valid/2
# 		Copying /home/jupyter/data/imagenet_style/cifar10/valid/7
# 		Copying /home/jupyter/data/imagenet_style/cifar10/valid/8
# 		Copying /home/jupyter/data/imagenet_style/cifar10/valid/3
# 		Copying /home/jupyter/data/imagenet_style/cifar10/valid/5
# 		Copying /home/jupyter/data/imagenet_style/cifar10/valid/0
# 	Copying cifar10/test
# 		Copying /home/jupyter/data/imagenet_style/cifar10/test
# 		Copying /home/jupyter/data/imagenet_style/cifar10/test
# 		Copying /home/jupyter/data/imagenet_style/cifar10/test
# 		Copying /home/jupyter/data/imagenet_style/cifar10/test
# 		Copying /home/jupyter/data/imagenet_style/cifar10/test
# 		Copying /home/jupyter/data/imagenet_style/cifar10/test
# 		Copying /home/jupyter/data/imagenet_style/cifar10/test
# 		Copying /home/jupyter/data/imagenet_style/cifar10/test
# 		Copying /home/jupyter/data/imagenet_style/cifar10/test
# 		Copying /home/jupyter/data/imagenet_style/cifar10/test
# Copying cifar10_tiny
# 	Copying cifar10_tiny/train
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/train/0
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/train/1
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/train/2
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/train/3
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/train/4
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/train/5
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/train/6
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/train/7
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/train/8
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/train/9
# 	Copying cifar10_tiny/valid
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/valid/0
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/valid/1
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/valid/2
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/valid/3
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/valid/4
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/valid/5
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/valid/6
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/valid/7
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/valid/8
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/valid/9
# 	Copying cifar10_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/cifar10_tiny/test
# Copying mnist
# 	Copying mnist/train
# 		Copying /home/jupyter/data/imagenet_style/mnist/train/5
# 		Copying /home/jupyter/data/imagenet_style/mnist/train/0
# 		Copying /home/jupyter/data/imagenet_style/mnist/train/4
# 		Copying /home/jupyter/data/imagenet_style/mnist/train/1
# 		Copying /home/jupyter/data/imagenet_style/mnist/train/9
# 		Copying /home/jupyter/data/imagenet_style/mnist/train/2
# 		Copying /home/jupyter/data/imagenet_style/mnist/train/3
# 		Copying /home/jupyter/data/imagenet_style/mnist/train/6
# 		Copying /home/jupyter/data/imagenet_style/mnist/train/7
# 		Copying /home/jupyter/data/imagenet_style/mnist/train/8
# 	Copying mnist/valid
# 		Copying /home/jupyter/data/imagenet_style/mnist/valid/5
# 		Copying /home/jupyter/data/imagenet_style/mnist/valid/0
# 		Copying /home/jupyter/data/imagenet_style/mnist/valid/4
# 		Copying /home/jupyter/data/imagenet_style/mnist/valid/1
# 		Copying /home/jupyter/data/imagenet_style/mnist/valid/9
# 		Copying /home/jupyter/data/imagenet_style/mnist/valid/2
# 		Copying /home/jupyter/data/imagenet_style/mnist/valid/3
# 		Copying /home/jupyter/data/imagenet_style/mnist/valid/6
# 		Copying /home/jupyter/data/imagenet_style/mnist/valid/7
# 		Copying /home/jupyter/data/imagenet_style/mnist/valid/8
# 	Copying mnist/test
# 		Copying /home/jupyter/data/imagenet_style/mnist/test
# 		Copying /home/jupyter/data/imagenet_style/mnist/test
# 		Copying /home/jupyter/data/imagenet_style/mnist/test
# 		Copying /home/jupyter/data/imagenet_style/mnist/test
# 		Copying /home/jupyter/data/imagenet_style/mnist/test
# 		Copying /home/jupyter/data/imagenet_style/mnist/test
# 		Copying /home/jupyter/data/imagenet_style/mnist/test
# 		Copying /home/jupyter/data/imagenet_style/mnist/test
# 		Copying /home/jupyter/data/imagenet_style/mnist/test
# 		Copying /home/jupyter/data/imagenet_style/mnist/test
# Copying mnist_tiny
# 	Copying mnist_tiny/train
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/train/0
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/train/1
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/train/2
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/train/3
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/train/4
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/train/5
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/train/6
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/train/7
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/train/8
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/train/9
# 	Copying mnist_tiny/valid
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/valid/0
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/valid/1
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/valid/2
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/valid/3
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/valid/4
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/valid/5
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/valid/6
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/valid/7
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/valid/8
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/valid/9
# 	Copying mnist_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/mnist_tiny/test
# Copying fashion_mnist
# 	Copying fashion_mnist/train
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/train/9
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/train/0
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/train/3
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/train/2
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/train/7
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/train/5
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/train/1
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/train/6
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/train/4
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/train/8
# 	Copying fashion_mnist/valid
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/valid/9
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/valid/0
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/valid/3
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/valid/2
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/valid/7
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/valid/5
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/valid/1
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/valid/6
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/valid/4
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/valid/8
# 	Copying fashion_mnist/test
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/test
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/test
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/test
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/test
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/test
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/test
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/test
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/test
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/test
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist/test
# Copying fashion_mnist_tiny
# 	Copying fashion_mnist_tiny/train
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/train/0
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/train/1
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/train/2
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/train/3
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/train/4
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/train/5
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/train/6
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/train/7
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/train/8
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/train/9
# 	Copying fashion_mnist_tiny/valid
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/valid/0
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/valid/1
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/valid/2
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/valid/3
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/valid/4
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/valid/5
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/valid/6
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/valid/7
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/valid/8
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/valid/9
# 	Copying fashion_mnist_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/test
# 		Copying /home/jupyter/data/imagenet_style/fashion_mnist_tiny/test
