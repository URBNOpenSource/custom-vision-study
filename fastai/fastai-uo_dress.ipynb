# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *
from pathlib import Path
import util
import warnings
warnings.filterwarnings(action='once')

# %% [markdown]
# ## User Params

# %%
basepath = Path('/home/jupyter/data')
dataset_name = 'uo_dress'
n_epoch = 100

# %% [markdown]
# ## Derived Params and Helpers

# %%
path_img = basepath/'imagenet_style'/dataset_name
labels_file = basepath/dataset_name/'labels.csv'

# %%
def create_learner(data, savename='dummy', patience=8, modeltype=models.resnet34):
    learn = create_cnn(data, 
                       modeltype, 
                       metrics=error_rate, 
                       callback_fns=[partial(SaveModelCallback, name=savename), 
                                     partial(EarlyStoppingCallback, patience=patience),
                                     ShowGraph])   
    return learn

# %% [markdown]
# ## Create dataset

# %%
data = ImageDataBunch.from_folder(path_img, 
                                  train='train', 
                                  valid='valid', 
                                  test='test', 
                                  ds_tfms=get_transforms(), 
                                  size=224)
data.normalize(imagenet_stats)

# %%
print(data.classes)
# Out:
# ['floral', 'not_dress', 'solid_color', 'stripes']

# %% [markdown]
# ## Display dataset

# %%
data.show_batch(rows=6)

# %% [markdown]
# ## Train a standard transfer learning model (stage 1)

# %%
learn = create_learner(data, 'stage1-bestmodel')
learn.fit_one_cycle(n_epoch)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='12' class='' max='100', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       12.00% [12/100 08:41<1:03:43]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.928811</th>
#     <th>0.457915</th>
#     <th>0.147059</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.576249</th>
#     <th>0.336673</th>
#     <th>0.102941</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.421974</th>
#     <th>0.290211</th>
#     <th>0.097426</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.359036</th>
#     <th>0.271983</th>
#     <th>0.093750</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.300393</th>
#     <th>0.262434</th>
#     <th>0.086397</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.263033</th>
#     <th>0.241389</th>
#     <th>0.084559</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.277091</th>
#     <th>0.242457</th>
#     <th>0.080882</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.231246</th>
#     <th>0.228696</th>
#     <th>0.075368</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.201122</th>
#     <th>0.233433</th>
#     <th>0.079044</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.175898</th>
#     <th>0.259085</th>
#     <th>0.091912</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.169636</th>
#     <th>0.242985</th>
#     <th>0.082721</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.162763</th>
#     <th>0.245616</th>
#     <th>0.077206</th>
#   </tr>
#   <tr>
#
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='5', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5/5 00:03<00:00]
#     </div>
# Epoch 13: early stopping

# %% [markdown]
# ### Show results from generic evaluation tool

# %%
results_val = util.eval_rollup(labels_file, learn, evalset='val')
# Out:
# Dataset: val
# {'sklearn': {'acc': 0.9246323529411765,
#              'auc_avg': 0.9875207212785985,
#              'auc_indiv': array([0.985821, 0.998796, 0.982052, 0.983415]),
#              'confmat': array([[138,   0,  12,   0],
#        [  1,  61,   2,   0],
#        [ 10,   0, 267,   2],
#        [  6,   0,   8,  37]]),
#              'report': '             precision    recall  f1-score   support\n'
#                        '\n'
#                        '     floral       0.89      0.92      0.90       150\n'
#                        '  not_dress       1.00      0.95      0.98        64\n'
#                        'solid_color       0.92      0.96      0.94       279\n'
#                        '    stripes       0.95      0.73      0.82        51\n'
#                        '\n'
#                        'avg / total       0.93      0.92      0.92       '
#                        '544\n'}}
# /home/jupyter/tutorials/util.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_keep['name'] = [d.split('/')[-1] for d in df_keep.name.tolist()]

# %%
results_test, y_true, y_pred, scores, class_labels = util.eval_rollup(labels_file, learn, evalset='test')
# Out:
# Dataset: test
# {'sklearn': {'acc': 0.926605504587156,
#              'auc_avg': 0.9851900290319527,
#              'auc_indiv': array([0.985741, 0.977645, 0.983271, 0.994103]),
#              'confmat': array([[135,   0,   5,   2],
#        [  5,  63,   6,   1],
#        [ 13,   1, 266,   4],
#        [  1,   0,   2,  41]]),
#              'report': '             precision    recall  f1-score   support\n'
#                        '\n'
#                        '     floral       0.88      0.95      0.91       142\n'
#                        '  not_dress       0.98      0.84      0.91        75\n'
#                        'solid_color       0.95      0.94      0.94       284\n'
#                        '    stripes       0.85      0.93      0.89        44\n'
#                        '\n'
#                        'avg / total       0.93      0.93      0.93       '
#                        '545\n'}}

# %% [markdown]
# ### Show results using FastAI to confirm matches

# %%
# Confirm fastai reporting matching the generic one used for other platforms
# Some formatting work needed below to run on test and not validation dataset
y_true_num = tensor([data.classes.index(z) for z in y_true])  # Convert strings to numbers (tensor)
preds,y,losses = learn.get_preds(with_loss=True, is_test=True)
interp = ClassificationInterpretation(data, preds, tensor(y_true_num), losses)
interp.plot_top_losses(15, figsize=(15,11))
interp.plot_confusion_matrix(figsize=(6,6), dpi=60)

# %% [markdown]
# Fastai confusion matrix matches the generic one for the test dataset.

# %% [markdown]
# ## Unfreezing, fine-tuning, and learning rates

# %% [markdown]
# First let's try just unfreezing the previously trained model and continue running some more training to see how well it can do.

# %%
learn = create_learner(data, 'unfreeze-bestmodel')
learn.load('stage1-bestmodel')
learn.unfreeze()
learn.fit_one_cycle(n_epoch)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9' class='' max='100', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       9.00% [9/100 07:17<1:13:43]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.212899</th>
#     <th>0.255519</th>
#     <th>0.097426</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.153469</th>
#     <th>0.224421</th>
#     <th>0.075368</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.154114</th>
#     <th>0.323202</th>
#     <th>0.082721</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.150317</th>
#     <th>0.267049</th>
#     <th>0.084559</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.138249</th>
#     <th>0.274833</th>
#     <th>0.090074</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.142363</th>
#     <th>0.290292</th>
#     <th>0.099265</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.158350</th>
#     <th>0.280466</th>
#     <th>0.090074</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.158044</th>
#     <th>0.342325</th>
#     <th>0.091912</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.161508</th>
#     <th>0.307332</th>
#     <th>0.095588</th>
#   </tr>
#   <tr>
#
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='5', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5/5 00:03<00:00]
#     </div>
# Epoch 10: early stopping

# %%
results_test, y_true, y_pred, scores, class_labels = util.eval_rollup(labels_file, learn, evalset='test')
# Out:
# Dataset: test
# {'sklearn': {'acc': 0.926605504587156,
#              'auc_avg': 0.9843160037348149,
#              'auc_indiv': array([0.986344, 0.973418, 0.984715, 0.992787]),
#              'confmat': array([[131,   0,   9,   2],
#        [  3,  64,   8,   0],
#        [ 13,   1, 269,   1],
#        [  2,   0,   1,  41]]),
#              'report': '             precision    recall  f1-score   support\n'
#                        '\n'
#                        '     floral       0.88      0.92      0.90       142\n'
#                        '  not_dress       0.98      0.85      0.91        75\n'
#                        'solid_color       0.94      0.95      0.94       284\n'
#                        '    stripes       0.93      0.93      0.93        44\n'
#                        '\n'
#                        'avg / total       0.93      0.93      0.93       '
#                        '545\n'}}
# /home/jupyter/tutorials/util.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_keep['name'] = [d.split('/')[-1] for d in df_keep.name.tolist()]

# %% [markdown]
# ## Unfreeze but use identified learning rates

# %% [markdown]
# Now let's go back to the original model that only trained the head again.
# But this time, we'll find the best learning rate to use for this, and then use those learning rates with the unfrozen model.

# %% [markdown]
# First, find and plot the learning rates using lr_find.

# %%
learn = create_learner(data)
learn.load('stage1-bestmodel')
learn.callback_fns = [Recorder]  # Need to flush callbacks or else lr_find crashes    
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# Now that we have the learning rate range, let's feed that into the model and rerun

# %%
# Reload with new savename
learn = create_learner(data, 'stage2-bestmodel')
learn.load('stage1-bestmodel')

# Unfreeze and kick off 
learn.unfreeze()
learn.fit_one_cycle(n_epoch, max_lr=slice(1e-5,1e-3))
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9' class='' max='100', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       9.00% [9/100 07:15<1:13:21]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.180553</th>
#     <th>0.231527</th>
#     <th>0.079044</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.167680</th>
#     <th>0.228687</th>
#     <th>0.079044</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.161569</th>
#     <th>0.236289</th>
#     <th>0.086397</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.143908</th>
#     <th>0.241076</th>
#     <th>0.080882</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.117038</th>
#     <th>0.231042</th>
#     <th>0.071691</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.108769</th>
#     <th>0.252501</th>
#     <th>0.084559</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.091657</th>
#     <th>0.245073</th>
#     <th>0.071691</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.081800</th>
#     <th>0.268605</th>
#     <th>0.080882</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.069420</th>
#     <th>0.283909</th>
#     <th>0.080882</th>
#   </tr>
#   <tr>
#
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='5' class='' max='5', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [5/5 00:03<00:00]
#     </div>
# Epoch 10: early stopping

# %%
results_test, y_true, y_pred, scores, class_labels = util.eval_rollup(labels_file, learn, evalset='test')
# Out:
# Dataset: test
# {'sklearn': {'acc': 0.926605504587156,
#              'auc_avg': 0.985919421159572,
#              'auc_indiv': array([0.986405, 0.978184, 0.98485 , 0.994239]),
#              'confmat': array([[134,   0,   5,   3],
#        [  4,  64,   6,   1],
#        [ 14,   1, 266,   3],
#        [  2,   0,   1,  41]]),
#              'report': '             precision    recall  f1-score   support\n'
#                        '\n'
#                        '     floral       0.87      0.94      0.91       142\n'
#                        '  not_dress       0.98      0.85      0.91        75\n'
#                        'solid_color       0.96      0.94      0.95       284\n'
#                        '    stripes       0.85      0.93      0.89        44\n'
#                        '\n'
#                        'avg / total       0.93      0.93      0.93       '
#                        '545\n'}}

# %% [markdown]
# ## Try Resnet50

# %%
data = ImageDataBunch.from_folder(path_img, 
                                  train='train', 
                                  valid='valid', 
                                  test='test', 
                                  ds_tfms=get_transforms(), 
                                  size=299,
                                  bs=32)
data.normalize(imagenet_stats)

# %% [markdown]
# ### Try training just the head

# %%
learn = create_learner(data, 'resnet50-stage1-bestmodel', modeltype=models.resnet50)
learn.fit_one_cycle(n_epoch)
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='14' class='' max='100', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       14.00% [14/100 31:43<3:14:52]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.468465</th>
#     <th>0.287810</th>
#     <th>0.084559</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.329154</th>
#     <th>0.254921</th>
#     <th>0.086397</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.266084</th>
#     <th>0.230838</th>
#     <th>0.080882</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.219798</th>
#     <th>0.213842</th>
#     <th>0.075368</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.199969</th>
#     <th>0.215420</th>
#     <th>0.079044</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.210217</th>
#     <th>0.224645</th>
#     <th>0.077206</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.177864</th>
#     <th>0.210861</th>
#     <th>0.073529</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.163686</th>
#     <th>0.229194</th>
#     <th>0.064338</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.158306</th>
#     <th>0.214422</th>
#     <th>0.077206</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.137121</th>
#     <th>0.238942</th>
#     <th>0.073529</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.124557</th>
#     <th>0.236494</th>
#     <th>0.088235</th>
#   </tr>
#   <tr>
#     <th>12</th>
#     <th>0.129889</th>
#     <th>0.225028</th>
#     <th>0.077206</th>
#   </tr>
#   <tr>
#     <th>13</th>
#     <th>0.118241</th>
#     <th>0.260035</th>
#     <th>0.088235</th>
#   </tr>
#   <tr>
#     <th>14</th>
#     <th>0.111512</th>
#     <th>0.250020</th>
#     <th>0.084559</th>
#   </tr>
#   <tr>
#
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9' class='' max='9', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [9/9 00:07<00:00]
#     </div>
# Epoch 15: early stopping

# %%
results_test, y_true, y_pred, scores, class_labels = util.eval_rollup(labels_file, learn, evalset='test')
# Out:
# Dataset: test
# {'sklearn': {'acc': 0.926605504587156,
#              'auc_avg': 0.9799659657453513,
#              'auc_indiv': array([0.986702, 0.951433, 0.984769, 0.996961]),
#              'confmat': array([[132,   0,   8,   2],
#        [  3,  63,   9,   0],
#        [ 10,   0, 272,   2],
#        [  1,   0,   5,  38]]),
#              'report': '             precision    recall  f1-score   support\n'
#                        '\n'
#                        '     floral       0.90      0.93      0.92       142\n'
#                        '  not_dress       1.00      0.84      0.91        75\n'
#                        'solid_color       0.93      0.96      0.94       284\n'
#                        '    stripes       0.90      0.86      0.88        44\n'
#                        '\n'
#                        'avg / total       0.93      0.93      0.93       '
#                        '545\n'}}
# /home/jupyter/tutorials/util.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_keep['name'] = [d.split('/')[-1] for d in df_keep.name.tolist()]

# %% [markdown]
# ### Unfreeze, finetune with learning rates

# %% [markdown]
# Get the learning rate separately, like before

# %%
learn = create_learner(data, modeltype=models.resnet50)
learn.load('resnet50-stage1-bestmodel')
learn.callback_fns = [Recorder]  # Need to flush callbacks or else lr_find crashes    
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# Reload the transfer learning results, unfreeze, and train using the range of learning rates.

# %%
# Reload with new savename
learn = create_learner(data, 'resnet50-stage2-bestmodel', modeltype=models.resnet50)
learn.load('resnet50-stage1-bestmodel')

# Unfreeze and kick off 
learn.unfreeze()
learn.fit_one_cycle(n_epoch, max_lr=slice(1e-6,1e-4))
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='11' class='' max='100', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       11.00% [11/100 32:33<4:23:26]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.146622</th>
#     <th>0.219020</th>
#     <th>0.080882</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.132143</th>
#     <th>0.216019</th>
#     <th>0.077206</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.126370</th>
#     <th>0.209346</th>
#     <th>0.071691</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.121646</th>
#     <th>0.208239</th>
#     <th>0.071691</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.131120</th>
#     <th>0.214694</th>
#     <th>0.071691</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.112422</th>
#     <th>0.214792</th>
#     <th>0.071691</th>
#   </tr>
#   <tr>
#     <th>7</th>
#     <th>0.102617</th>
#     <th>0.216855</th>
#     <th>0.073529</th>
#   </tr>
#   <tr>
#     <th>8</th>
#     <th>0.106326</th>
#     <th>0.235673</th>
#     <th>0.080882</th>
#   </tr>
#   <tr>
#     <th>9</th>
#     <th>0.105084</th>
#     <th>0.223962</th>
#     <th>0.069853</th>
#   </tr>
#   <tr>
#     <th>10</th>
#     <th>0.083951</th>
#     <th>0.225829</th>
#     <th>0.075368</th>
#   </tr>
#   <tr>
#     <th>11</th>
#     <th>0.081899</th>
#     <th>0.228312</th>
#     <th>0.066176</th>
#   </tr>
#   <tr>
#
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='9' class='' max='9', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [9/9 00:07<00:00]
#     </div>
# Epoch 12: early stopping

# %%
results_test, y_true, y_pred, scores, class_labels = util.eval_rollup(labels_file, learn, evalset='test')
# Out:
# Dataset: test
# {'sklearn': {'acc': 0.9357798165137615,
#              'auc_avg': 0.9805835499538551,
#              'auc_indiv': array([0.985688, 0.953078, 0.986698, 0.99687 ]),
#              'confmat': array([[132,   0,   6,   4],
#        [  3,  65,   7,   0],
#        [  8,   0, 274,   2],
#        [  0,   0,   5,  39]]),
#              'report': '             precision    recall  f1-score   support\n'
#                        '\n'
#                        '     floral       0.92      0.93      0.93       142\n'
#                        '  not_dress       1.00      0.87      0.93        75\n'
#                        'solid_color       0.94      0.96      0.95       284\n'
#                        '    stripes       0.87      0.89      0.88        44\n'
#                        '\n'
#                        'avg / total       0.94      0.94      0.94       '
#                        '545\n'}}
